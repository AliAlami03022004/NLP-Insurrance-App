# %% [markdown]
# # Modeling Workflow Notebook
#
# This notebook gives executable cells for the main NLP/ML workflow without embedding the whole monolithic project in one file.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parents[0]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %% [markdown]
# ## Load Service Layer

# %%
from backend.services import get_dataset_overview, get_model_performance_tables, ask_question

get_dataset_overview()

# %% [markdown]
# ## Inspect Model Comparison Tables

# %%
tables = get_model_performance_tables()
tables['stars']

# %% [markdown]
# ## Ask a Routed RAG Question

# %%
result = ask_question(
    'Which is the best insurer overall by stars?',
    generative_backend='ollama',
    generative_model='llama3.1:8b',
)
result['hybrid_answer']

# %% [markdown]
# ## Notes
# - `backend/services.py` is the main orchestration layer.
# - All reusable training and inference logic now lives inside `NLP_ProjetV2_modular/backend/`.
